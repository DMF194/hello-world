# %%
#Load Libraries like numbpy,pandas,matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.arange(0, 5, 0.1)
#y = np.sin(x)
y=x**3
plt.plot(x, y)
plt.figure(figsize=(5,3), dpi=200)

# %%
#x = np.arange(0, 5, 0.1)
#y = np.sin(x)
#y=x**3
plt.plot([1,2,3,4],[2,4,6,8])

# %% [markdown]
# #Basic Graph

# %%
x=[1,2,3,4]
y=[2,4,6,8]
plt.plot(x,y)
plt.show()

# %%
detrend(x: np.ndarray)
# Out:
#   File "<ipython-input-11-68d7f9c5477a>", line 1
#     detrend(x: np.ndarray)
#              ^
# SyntaxError: invalid syntax

# %%
c
plt.xticks([2,4])
plt.yticks([2,5])
# Out:
# ([<matplotlib.axis.YTick at 0x297b41da850>,
# ...
#  [Text(0, 0, ''), Text(0, 0, '')])

# %%
plt.figure(figsize=(5,3), dpi=200)
x=[1,2,3,4]
y=[2,4,6,8]
plt.plot(x,y,color='red',marker='o',linestyle='dashed',label='2x')
plt.plot('My First Graph')
plt.xticks([2,4,6,10])
plt.yticks([2,5])
plt.legend()
plt.savefig('my1stGraph.png', dpi=150)

plt.show()

# %% [markdown]
# ##BarChart

# %%
labels=['A','B','C']
values=[1,4,2]
plt.figure(figsize=(6,4),dpi=150)
bar=plt.bar(labels,values)

pattern=['o','+','-']
for bars in bar:
    bars.set_hatch(pattern.pop(0))
#bar[0].set_hatch('/')
#bar[1].set_hatch('-')
#bar[2].set_hatch('+')
plt.savefig('my2ndGraph.png', dpi=150)
plt.show()

# %%
labels=['A','B','C']
values=[1,4,2]
plt.figure(figsize=(6,4),dpi=150)
plt.pie(values)
pie1=plt.pie(values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-c9fdea0fd1c6> in <module>
#       4 plt.pie(values)
#       5 pie1=plt.pie(values)
# ----> 6 pie1[0].set_hatch('/')
#       7 plt.show()
#
# AttributeError: 'list' object has no attribute 'set_hatch'

# %% [markdown]
# #REAL WORLD Example
